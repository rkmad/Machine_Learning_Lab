# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Part-I:-Preprocessing-and-EDA" data-toc-modified-id="Part-I:-Preprocessing-and-EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Part I: Preprocessing and EDA</a></span><ul class="toc-item"><li><span><a href="#Analyze-Missingness" data-toc-modified-id="Analyze-Missingness-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Analyze Missingness</a></span></li><li><span><a href="#Functions-for-EDA" data-toc-modified-id="Functions-for-EDA-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Functions for EDA</a></span></li><li><span><a href="#Problem-1:-Dataset-Import-&amp;-Cleaning" data-toc-modified-id="Problem-1:-Dataset-Import-&amp;-Cleaning-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Problem 1: Dataset Import &amp; Cleaning</a></span></li><li><span><a href="#Problem-2:-Inventory-Management" data-toc-modified-id="Problem-2:-Inventory-Management-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Problem 2: Inventory Management</a></span></li><li><span><a href="#Problem-3:-Why-did-customers-make-returns?" data-toc-modified-id="Problem-3:-Why-did-customers-make-returns?-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Problem 3: Why did customers make returns?</a></span></li></ul></li><li><span><a href="#Part-II:-Machine-Learning-and-Business-Use-Case" data-toc-modified-id="Part-II:-Machine-Learning-and-Business-Use-Case-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Part II: Machine Learning and Business Use Case</a></span><ul class="toc-item"><li><span><a href="#Problem-4:-Feature-Engineering" data-toc-modified-id="Problem-4:-Feature-Engineering-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Problem 4: Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Step-1:-Create-the-dependent-variable" data-toc-modified-id="Step-1:-Create-the-dependent-variable-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Step 1: Create the dependent variable</a></span></li><li><span><a href="#Step-2:" data-toc-modified-id="Step-2:-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Step 2:</a></span></li><li><span><a href="#Step-3:" data-toc-modified-id="Step-3:-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Step 3:</a></span></li></ul></li><li><span><a href="#Problem-5:-Fitting-Models" data-toc-modified-id="Problem-5:-Fitting-Models-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Problem 5: Fitting Models</a></span><ul class="toc-item"><li><span><a href="#REMOVE-FEATURES" data-toc-modified-id="REMOVE-FEATURES-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>REMOVE FEATURES</a></span></li><li><span><a href="#LABEL-ENCODING" data-toc-modified-id="LABEL-ENCODING-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>LABEL ENCODING</a></span></li><li><span><a href="#KNN-Model" data-toc-modified-id="KNN-Model-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>KNN Model</a></span></li><li><span><a href="#Confusion-matrices" data-toc-modified-id="Confusion-matrices-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Confusion matrices</a></span></li><li><span><a href="#Balance-classes-and-recalculate-Confusion-matricies?-Not-sure-if-possible-for-KNN-classifier" data-toc-modified-id="Balance-classes-and-recalculate-Confusion-matricies?-Not-sure-if-possible-for-KNN-classifier-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Balance classes and recalculate Confusion matricies? Not sure if possible for KNN classifier</a></span></li><li><span><a href="#XGBoost-Model" data-toc-modified-id="XGBoost-Model-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>XGBoost Model</a></span></li></ul></li><li><span><a href="#XGBoost-Random-Forest-Classifier" data-toc-modified-id="XGBoost-Random-Forest-Classifier-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>XGBoost Random Forest Classifier</a></span></li><li><span><a href="#XGBoost-Feature-Selection" data-toc-modified-id="XGBoost-Feature-Selection-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>XGBoost Feature Selection</a></span></li><li><span><a href="#slight-improvement-in-prediction-accuracy-with-reduced-feature-set" data-toc-modified-id="slight-improvement-in-prediction-accuracy-with-reduced-feature-set-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>slight improvement in prediction accuracy with reduced feature set</a></span></li><li><span><a href="#Problem-6:-Evaluating-Models" data-toc-modified-id="Problem-6:-Evaluating-Models-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Problem 6: Evaluating Models</a></span></li><li><span><a href="#Problem-7:-Feature-Engineering-Revisit" data-toc-modified-id="Problem-7:-Feature-Engineering-Revisit-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Problem 7: Feature Engineering Revisit</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import time
import random
import statsmodels.api as sm
import sklearn.model_selection as ms
from xgboost import XGBClassifier, XGBRFClassifier
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
sns.set(style = "whitegrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score, StratifiedKFold
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler,LabelEncoder
from sklearn import neighbors
from sklearn.metrics import mean_squared_log_error, mean_squared_error, confusion_matrix, roc_auc_score, f1_score, plot_roc_curve, roc_auc_score, roc_curve, RocCurveDisplay, auc
from sklearn.tree import DecisionTreeRegressor, export_graphviz

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Part I: Preprocessing and EDA
# - The data comes from a global e-retailer company, including orders from 2012 to 2015. Import the **Orders** dataset and do some basic EDA.
# - For problem 1 to 3, we mainly focus on data cleaning and data visualizations. You can use all the packages that you are familiar with to conduct some plots and also provide **brief interpretations** about your findings.
#
# - How will we handle missing values?
# - Coerce dates to datetime
# - USD to float64
# - Outliers and How to deal with?
# - Does any of the features look skewed? Should we transform them using Box-Cox, log, sqrt?
# - Which variables should we dummify?
# - Quick correlation plots. Variables with high corrleation to prices should be prioritized as predictors
# - How to deal with multi-collinearity?

# %%
# import Orders.csv
orders = pd.read_csv('./Data/Orders.csv')

# %%
orders
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# ...       ...                       ...        ...       ...             ...
# 51285   29002   IN-2015-KE1642066-42174    6/19/15   6/19/15        Same Day
# 51286   34337  US-2014-ZD21925140-41765     5/6/14   5/10/14  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147    8/26/12   8/31/12    Second Class
# 51288    9596   MX-2013-RB1979518-41322    2/17/13   2/21/13  Standard Class
# 51289    6147   MX-2013-MC1810093-41416    5/22/13   5/26/13    Second Class
#
# ...

# %%
orders.dtypes
# Out:
# Row.ID              int64
# Order.ID           object
# Order.Date         object
# Ship.Date          object
# Ship.Mode          object
# Customer.ID        object
# Customer.Name      object
# Segment            object
# Postal.Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product.ID         object
# Category           object
# Sub.Category       object
# Product.Name       object
# Sales              object
# Quantity            int64
# Discount          float64
# Profit             object
# Shipping.Cost     float64
# Order.Priority     object
# dtype: object

# %%
object
# Out:
# object

# %%
# USD columns
usd = ['Sales', 'Profit']

# date columns
date_ = ['Order.Date', 'Ship.Date']

# %%
orders['Sales'] = orders['Sales'].str.replace('$', '').str.replace(',', '')
orders['Profit'] = orders['Profit'].str.replace('$', '').str.replace(',', '')
# Out:
# <ipython-input-7-117bc5c3531c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders['Sales'] = orders['Sales'].str.replace('$', '').str.replace(',', '')
# <ipython-input-7-117bc5c3531c>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders['Profit'] = orders['Profit'].str.replace('$', '').str.replace(',', '')

# %%
orders['Sales'] = orders['Sales'].astype('float64', copy=False)
orders['Profit'] = orders['Profit'].astype('float64', copy=False)

# %%
orders['Order.Date']= pd.to_datetime(orders['Order.Date'])
orders['Ship.Date']= pd.to_datetime(orders['Ship.Date'])

# %%
orders.dtypes
# Out:
# Row.ID                     int64
# Order.ID                  object
# Order.Date        datetime64[ns]
# Ship.Date         datetime64[ns]
# Ship.Mode                 object
# Customer.ID               object
# Customer.Name             object
# Segment                   object
# Postal.Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product.ID                object
# Category                  object
# Sub.Category              object
# Product.Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping.Cost            float64
# Order.Priority            object
# dtype: object

# %% [markdown]
# ### Analyze Missingness

# %%
# Identify missing rows and columns
missingRows = pd.isnull(orders).sum(axis=1) > 0
missingCols = pd.isnull(orders).sum(axis=0) > 0
print('The columns with missingness are: %s' % (orders.columns[missingCols]))
print('Number of rows with missingness are: %s' % (np.sum(missingRows)))
# Out:
# The columns with missingness are: Index(['Postal.Code'], dtype='object')
# Number of rows with missingness are: 41296

# %%
# for columns with missing values, what percent missing?
# Percentage of missing values in columns that are missing values:
def missingValPercent(col, df):
    val = df[col].isnull().sum()/df.shape[0]*100
    return round(val, 1)

missing_cols = pd.concat([pd.Series(orders.columns[missingCols]), 
                          pd.Series([missingValPercent(ele, df = orders) 
                                     for ele in orders.columns[missingCols]])], axis=1, keys=['column', 'percent_missing'])
pd.set_option('display.max_rows', None)
missing_cols
# Out:
#         column  percent_missing
# 0  Postal.Code             80.5

# %% [markdown]
# ### Functions for EDA

# %%
cat = orders.select_dtypes(["object","category"])
cont = orders.select_dtypes(["float64","int64"])

# %%
cat.head(5)
# Out:
#                    Order.ID     Ship.Mode   Customer.ID     Customer.Name  \
# 0  CA-2014-AB10015140-41954   First Class  AB-100151402     Aaron Bergman
# 1    IN-2014-JR162107-41675  Second Class     JR-162107     Justin Ritter
# 2    IN-2014-CR127307-41929   First Class     CR-127307      Craig Reiter
# 3   ES-2014-KM1637548-41667   First Class    KM-1637548  Katherine Murray
# 4   SG-2014-RH9495111-41948      Same Day    RH-9495111       Rick Hansen
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
# ...

# %%
cont.head(5)
# Out:
#    Row.ID  Postal.Code    Sales  Quantity  Discount  Profit  Shipping.Cost
# 0   40098      73120.0   221.98         2       0.0   62.15          40.77
# 1   26341          NaN  3709.40         9       0.1 -288.77         923.63
# 2   25330          NaN  5175.17         9       0.1  919.97         915.49
# 3   13524          NaN  2892.51         5       0.1  -96.54         910.16
# 4   47221          NaN  2832.96         8       0.0  311.52         903.04

# %% [markdown]
# ### Problem 1: Dataset Import & Cleaning
# Check **"Profit"** and **"Sales"** in the dataset, convert these two columns to numeric type.

# %%
profit = orders.Profit
sales = orders.Sales

# %%
plt.hist(profit, bins=50)
profit.describe()
# Out:
# count    51290.000000
# mean        28.610970
# std        174.341066
# min      -6599.980000
# 25%          0.000000
# 50%          9.240000
# 75%         36.810000
# max       8399.980000
# Name: Profit, dtype: float64

# %%
plt.hist(sales, bins=50)
sales.describe()
# Out:
# count    51290.000000
# mean       246.490685
# std        487.565388
# min          0.440000
# 25%         30.762500
# 50%         85.055000
# 75%        251.055000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# ### Problem 2: Inventory Management
# - Retailers that depend on seasonal shoppers have a particularly challenging job when it comes to inventory management. Your manager is making plans for next year's inventory.
# - He wants you to answer the following questions:
#     1. Is there any seasonal trend of inventory in the company?
#     2. Is the seasonal trend the same for different categories?
#
# - ***Hint:*** For each order, it has an attribute called `Quantity` that indicates the number of product in the order. If an order contains more than one product, there will be multiple observations of the same order.

# %%
orders.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 9597    21761   IN-2014-BM1114066-41916 2014-10-04 2014-10-08  Standard Class
# 44644   33351  CA-2014-RD19480140-41975 2014-12-02 2014-12-08  Standard Class
# 44648   32967  CA-2015-RD19480140-42297 2015-10-20 2015-10-27  Standard Class
# 28666   30825   IN-2015-JG1580592-42120 2015-04-26 2015-04-30  Standard Class
# 46241   10205   US-2015-MW1822018-42095 2015-04-01 2015-04-01        Same Day
#
#         Customer.ID Customer.Name    Segment  Postal.Code          City  \
# 9597     BM-1114066  Becky Martin   Consumer          NaN    Sagamihara
# 44644  RD-194801402   Rick Duston   Consumer      47374.0      Richmond
# 44648  RD-194801402   Rick Duston   Consumer      77095.0       Houston
# 28666    JG-1580592    John Grady  Corporate          NaN  New Plymouth
# 46241    MW-1822018  Mitch Webber   Consumer          NaN     Vassouras
#
# ...

# %%
# 1. Is there any seasonal trend of inventory in the company?

orders['Order.Date']= pd.to_datetime(orders['Order.Date'])
orders['Ship.Date']= pd.to_datetime(orders['Ship.Date'])
orders['order.month']= orders['Order.Date'].dt.month

# %%
orders.groupby('order.month')['Quantity'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order.month'>

# %%
# 2. Is the seasonal trend the same for different categories?


for index, group in orders.groupby(['Category']):
    group_aggregate = group.groupby(['order.month'])['Quantity'].sum()
    group_aggregate.plot(y='Quantity', label=index, legend=True)

# %% [markdown]
# ### Problem 3: Why did customers make returns?
# - Your manager required you to give a brief report (**Plots + Interpretations**) on returned orders.
#
# 	1. How much profit did we lose due to returns each year?
#
# 	2. How many customer returned more than once? more than 5 times?
#
# 	3. Which regions are more likely to return orders?
#
# 	4. Which categories (sub-categories) of products are more likely to be returned?
#
# - ***Hint:*** Merge the **Returns** dataframe with the **Orders** dataframe using `Order.ID`.

# %%
returns = pd.read_csv('./Data/Returns.csv')

# %%
returns.sample(5)
# Out:
#      Returned                 Order ID           Region
# 588       Yes  US-2013-KA1652582-41360  Central America
# 1017      Yes  IN-2014-DM1301527-41919     Eastern Asia
# 714       Yes  ES-2015-CM1223545-42327   Western Europe
# 524       Yes  ES-2014-SV2093545-41674   Western Europe
# 413       Yes  IN-2015-Dl1360058-42364    Southern Asia

# %%
pd.merge?

# %%
ord_ret = pd.merge(orders, returns, left_on='Order.ID', right_on='Order ID')

# %%
# 1. How much profit did we lose due to returns each year?
np.sum(ord_ret.Profit)
# Out:
# 61370.75

# %%
np.sum(ord_ret[ord_ret['Profit']<0].Profit)
# Out:
# -36832.6

# %%
ord_ret.head(5)
# Out:
#    Row.ID                  Order.ID Order.Date  Ship.Date    Ship.Mode  \
# 0   30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
# 1   30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
# 2   30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
# 3   30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
# 4   30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19  First Class
#
#    Customer.ID   Customer.Name    Segment  Postal.Code    City        State  \
# 0  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
# 1  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
# 2  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
# 3  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
# 4  PB-19210127  Phillip Breyer  Corporate          NaN  Taipei  Taipei City
#
#   Country      Region_x        Market   Product.ID    Category Sub.Category  \
# ...

# %%
ord_ret['Returned'].value_counts()
# Out:
# Yes    2220
# Name: Returned, dtype: int64

# %%
# 2. How many customer returned more than once? 
np.sum(ord_ret['Customer.Name'].value_counts() > 1)
# Out:
# 448

# %%
# 2. ... more than 5 times?
np.sum(ord_ret['Customer.Name'].value_counts() > 5)
# Out:
# 124

# %%
ord_ret.groupby('Customer.Name').count() >1
# Out:
#                         Row.ID  Order.ID  Order.Date  Ship.Date  Ship.Mode  \
# Customer.Name
# Aaron Bergman             True      True        True       True       True
# Aaron Hawkins             True      True        True       True       True
# Aaron Smayling            True      True        True       True       True
# Adam Shillingsburg        True      True        True       True       True
# Adrian Barton             True      True        True       True       True
# Adrian Hane               True      True        True       True       True
# Aimee Bixby              False     False       False      False      False
# Alan Barnes               True      True        True       True       True
# Alan Dominguez            True      True        True       True       True
# Alan Haines               True      True        True       True       True
# Alan Schoenberger         True      True        True       True       True
# ...

# %%
ord_ret['Customer.Name'].value_counts()
# Out:
# Patrick O'Brill           21
# Jeremy Pistek             20
# Tom Boeckenhauer          17
# Muhammed Yedwab           17
# Anne McFarland            15
# Greg Tran                 15
# Ben Ferrer                14
# Daniel Lacy               14
# Juliana Krohn             14
# Karl Braun                13
# Darren Koutras            13
# Andrew Gjertsen           13
# Julie Creighton           13
# Gary Mitchum              13
# Edward Hooks              13
# Erin Smith                13
# Eugene Hildebrand         12
# Sonia Sunley              11
# Harold Dahlen             11
# Astrea Jones              11
# Darrin Van Huff           11
# Toby Braunhardt           11
# Skye Norling              11
# Paul Knutson              11
# Anna Gayman               10
# Theresa Coyne             10
# Kristen Hastings          10
# Clay Ludtke               10
# Dean Braden               10
# Ann Blume                 10
# Sandra Glassco            10
# Alejandro Savely          10
# ...

# %%
# 3. Which regions are more likely to return orders?
ord_ret['Region_x'].value_counts() 
# calculate return ratio by region ####
# Out:
# Central America      248
# Western Europe       233
# Western US           177
# Oceania              154
# Southeastern Asia    140
# Eastern US           134
# South America        133
# Eastern Asia         131
# Southern Europe      112
# Southern Asia        111
# Western Asia         108
# Southern US           83
# Northern Europe       76
# Central US            74
# Caribbean             69
# Western Africa        60
# North Africa          51
# Eastern Europe        42
# Southern Africa       25
# Eastern Africa        18
# Central Africa        17
# Canada                15
# Central Asia           9
# Name: Region_x, dtype: int64

# %%
# 4. Which categories (sub-categories) of products are more likely to be returned?
ord_ret['Category'].value_counts()
# Out:
# Office Supplies    1348
# Technology          445
# Furniture           427
# Name: Category, dtype: int64

# %%
ord_ret['Sub.Category'].value_counts()
# Out:
# Binders        269
# Art            217
# Storage        212
# Paper          150
# Chairs         147
# Phones         145
# Accessories    138
# Labels         137
# Furnishings    135
# Bookcases      104
# Supplies       103
# Fasteners      102
# Envelopes       99
# Copiers         99
# Machines        63
# Appliances      59
# Tables          41
# Name: Sub.Category, dtype: int64

# %% [markdown]
# ## Part II: Machine Learning and Business Use Case

# %% [markdown]
# ### Problem 4: Feature Engineering
# #### Step 1: Create the dependent variable
# - First of all, we need to generate a categorical variable which indicates whether an order has been returned or not.
# - ***Hint:*** the returned orders’ IDs are contained in the dataset “returns”

# %%
ord_ret2 = pd.merge(orders, returns, left_on='Order.ID', right_on='Order ID', how='left')

# %%
returns
# Out:
#      Returned                  Order ID             Region
# 0         Yes  CA-2012-SA20830140-41210         Central US
# 1         Yes  IN-2012-PB19210127-41259       Eastern Asia
# 2         Yes  CA-2012-SC20095140-41174         Central US
# 3         Yes    IN-2015-JH158207-42140            Oceania
# 4         Yes    IN-2014-LC168857-41747            Oceania
# 5         Yes   ID-2013-AB1001527-41439       Eastern Asia
# 6         Yes   ES-2015-RA1994545-42218     Western Europe
# 7         Yes  CA-2014-TB21280140-41724         Central US
# 8         Yes  ES-2014-JF15295120-41924    Southern Europe
# 9         Yes   IN-2014-NM1844527-41800       Eastern Asia
# 10        Yes    IN-2015-GB145307-42260            Oceania
# 11        Yes    ES-2012-SC208458-41070     Western Europe
# 12        Yes  TU-2013-SF10200134-41417       Western Asia
# 13        Yes   ID-2015-RD1993092-42140            Oceania
# 14        Yes  CA-2014-TC21295140-41800        Southern US
# ...

# %%
ord_ret2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8653da664c02> in <module>
# ----> 1 ord_ret2
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
ord_ret2['Returned'].value_counts()
# Out:
# Yes    2220
# Name: Returned, dtype: int64

# %% [markdown]
# #### Step 2:
# - Your manager believes that **how long it took the order to ship** would affect whether the customer would return it or not.
# - He wants you to generate a feature which can measure how long it takes the company to process each order.
# - ***Hint:*** Process.Time = Ship.Date - Order.Date

# %%
ord_ret2['process.days'] = ord_ret2['Ship.Date'] - ord_ret2['Order.Date']

# %%
ord_ret2['process.days'] = ord_ret2['process.days'].dt.days

# %%
ord_ret2.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 29020   45059  RO-2014-TH11235107-41682 2014-02-12 2014-02-16  Standard Class
# 37610    4683   MX-2015-JM1586582-42137 2015-05-13 2015-05-17  Standard Class
# 19835   50080   TU-2015-DV3045134-42144 2015-05-20 2015-05-22    Second Class
# 7876     3899   MX-2013-JS1594093-41349 2013-03-16 2013-03-18    Second Class
# 27670   41294    EG-2014-FH436538-42003 2014-12-30 2015-01-03    Second Class
#
#        Customer.ID    Customer.Name      Segment  Postal.Code         City  \
# 29020  TH-11235107    Tiffany House    Corporate          NaN  Cluj-Napoca
# 37610   JM-1586582      John Murray     Consumer          NaN      Zapopan
# 19835   DV-3045134  Darrin Van Huff    Corporate          NaN    Eskisehir
# 7876    JS-1594093  Joni Sundaresam  Home Office          NaN      Managua
# 27670    FH-436538     Fred Hopkins    Corporate          NaN     Hurghada
#
# ...

# %%
ord_ret2[ord_ret2['Returned']==  'Yes']['process.days'].value_counts()
# Out:
# 4    619
# 5    483
# 6    313
# 2    284
# 3    220
# 7    125
# 0    115
# 1     61
# Name: process.days, dtype: int64

# %%
ret= ord_ret2[ord_ret2['Returned']==  'Yes']['process.days']
not_ret= ord_ret2[ord_ret2['Returned']!= 'Yes']['process.days']

plt.hist([ret,not_ret], bins=8, label=['returned','not returned'], density=True)
plt.title('Normalized Shipping delay time in days')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### Step 3:
#
# - If a product has been returned before, it may be returned again.
# - Let us generate a feature indictes how many times the product has been returned before.
# - If it never got returned, we just impute using 0.
# - ***Hint:*** Group by different Product.ID

# %%
ord_ret2.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 38808   47487   TU-2014-RP9855134-41969 2014-11-26 2014-11-30  Standard Class
# 26472   18607  ES-2012-PB19105139-40920 2012-01-12 2012-01-15     First Class
# 39482     967   MX-2014-FH1435082-41872 2014-08-21 2014-08-28  Standard Class
# 27320   28415    ID-2014-SA208307-41669 2014-01-30 2014-02-05  Standard Class
# 276     25831  IN-2013-ED13885144-41549 2013-10-02 2013-10-02        Same Day
#
#        Customer.ID Customer.Name      Segment  Postal.Code              City  \
# 38808   RP-9855134      Roy Phan    Corporate          NaN          Bagcilar
# 26472  PB-19105139  Peter Bühler     Consumer          NaN         Sheffield
# 39482   FH-1435082   Fred Harton     Consumer          NaN            Toluca
# 27320    SA-208307  Sue Ann Reed     Consumer          NaN          Ballarat
# 276    ED-13885144  Emily Ducich  Home Office          NaN  Ho Chi Minh City
#
# ...

# %%
#returned_num_times_df= ord_ret2.groupby('Product.ID').size().reset_index(name ='Return.Times')

#### need to only do this where Returned ==Yes

# %%
pd.DataFrame(ord_ret2[ord_ret2.Returned == 'Yes']['Product.ID'].value_counts())
# Out:
#              Product.ID
# OFF-FA-6129          12
# OFF-ST-6033           9
# OFF-AR-3499           6
# OFF-ST-6251           6
# OFF-ST-6031           6
# OFF-ST-5712           5
# OFF-BI-3724           5
# OFF-ST-5693           5
# OFF-BI-3723           5
# FUR-CH-5378           5
# OFF-AR-3494           5
# OFF-AR-3482           5
# OFF-AR-3548           5
# OFF-ST-5706           4
# OFF-AR-3528           4
# TEC-AC-5887           4
# OFF-LA-4657           4
# OFF-AR-6117           4
# FUR-CH-4523           4
# TEC-CO-4578           4
# OFF-FA-6196           4
# TEC-PH-5351           4
# OFF-BI-2895           4
# OFF-PA-4464           4
# FUR-FU-5728           4
# OFF-ST-6048           4
# FUR-CH-5395           4
# OFF-AR-3533           4
# OFF-AR-5933           4
# OFF-BI-3254           4
# OFF-LA-4678           4
# OFF-BI-3188           4
# OFF-ST-4267           4
# OFF-ST-6282           4
# OFF-AR-3456           4
# OFF-ST-4269           4
# OFF-AR-5918           4
# ...

# %%
returned_num_times_df = pd.DataFrame(ord_ret2[ord_ret2.Returned == 'Yes']['Product.ID'].value_counts().reset_index(name ='Returned.num.Times'))

# %%
returned_num_times_df
# Out:
#             index  Returned.num.Times
# 0     OFF-FA-6129                  12
# 1     OFF-ST-6033                   9
# 2     OFF-AR-3499                   6
# 3     OFF-ST-6251                   6
# 4     OFF-ST-6031                   6
# 5     OFF-ST-5712                   5
# 6     OFF-BI-3724                   5
# 7     OFF-ST-5693                   5
# 8     OFF-BI-3723                   5
# 9     FUR-CH-5378                   5
# 10    OFF-AR-3494                   5
# 11    OFF-AR-3482                   5
# 12    OFF-AR-3548                   5
# 13    OFF-ST-5706                   4
# 14    OFF-AR-3528                   4
# 15    TEC-AC-5887                   4
# 16    OFF-LA-4657                   4
# 17    OFF-AR-6117                   4
# 18    FUR-CH-4523                   4
# 19    TEC-CO-4578                   4
# 20    OFF-FA-6196                   4
# 21    TEC-PH-5351                   4
# 22    OFF-BI-2895                   4
# 23    OFF-PA-4464                   4
# ...

# %%
ord_ret2.groupby(['Product.ID']).agg('count')[['Sales']]
# Out:
#              Sales
# Product.ID
# FUR-BO-3174      2
# FUR-BO-3175      8
# FUR-BO-3176      6
# FUR-BO-3177      8
# FUR-BO-3409      8
# FUR-BO-3615     16
# FUR-BO-3616     20
# FUR-BO-3617     12
# FUR-BO-3618     19
# FUR-BO-3621      9
# FUR-BO-3623      1
# FUR-BO-3624     23
# FUR-BO-3625     19
# FUR-BO-3626     13
# FUR-BO-3627     22
# FUR-BO-3628     18
# FUR-BO-3629     22
# FUR-BO-3630     22
# FUR-BO-3631     13
# FUR-BO-3632      3
# FUR-BO-3634     20
# FUR-BO-3635     17
# FUR-BO-3636     20
# FUR-BO-3637     14
# FUR-BO-3638      8
# FUR-BO-3639     23
# FUR-BO-3640     24
# FUR-BO-3641     11
# FUR-BO-3642     22
# FUR-BO-3643      3
# FUR-BO-3644      1
# FUR-BO-3645      4
# FUR-BO-3646     13
# FUR-BO-3647     44
# FUR-BO-3648     20
# FUR-BO-3649      3
# FUR-BO-3650      1
# FUR-BO-3651      6
# FUR-BO-3652      9
# FUR-BO-3885     12
# FUR-BO-3886     19
# FUR-BO-3887     20
# FUR-BO-3888     13
# FUR-BO-3889     15
# FUR-BO-3890     19
# FUR-BO-3891     22
# ...

# %%
ord_ret3 = pd.merge(ord_ret2, returned_num_times_df, left_on='Product.ID', right_on='index', how='left')

# %%
ord_ret3['Returned.num.Times'] = ord_ret3['Returned.num.Times'].fillna(0)

# %%
ord_ret3.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 32231   11996  IT-2014-AH10120139-41909 2014-09-27 2014-10-02  Standard Class
# 50067   46076   TU-2014-KL6645134-41818 2014-06-28 2014-06-30     First Class
# 37015    5706   MX-2013-EL1373593-41572 2013-10-25 2013-10-29  Standard Class
# 32539   32581  US-2013-KW16435140-41614 2013-12-06 2013-12-12  Standard Class
# 4014    23648  IN-2015-GH14665144-42120 2015-04-26 2015-05-01  Standard Class
#
#         Customer.ID    Customer.Name      Segment  Postal.Code  \
# 32231   AH-10120139      Adrian Hane  Home Office          NaN
# 50067    KL-6645134     Ken Lonsdale     Consumer          NaN
# 37015    EL-1373593        Ed Ludwig  Home Office          NaN
# 32539  KW-164351402  Katrina Willman     Consumer      78745.0
# 4014    GH-14665144      Greg Hansen     Consumer          NaN
#
#                    City             State         Country           Region_x  \
# ...

# %%
ord_ret3.shape
# Out:
# (51290, 31)

# %%
ord_ret3.groupby('Sub.Category')['Returned.num.Times'].count().plot(kind='bar')
ord_ret3.groupby('Sub.Category')['Returned.num.Times'].count()
# Out:
# Sub.Category
# Accessories    3075
# Appliances     1742
# Art            4864
# Binders        6146
# Bookcases      2411
# Chairs         3434
# Copiers        2223
# Envelopes      2387
# Fasteners      2601
# Furnishings    3154
# Labels         2601
# Machines       1486
# Paper          3492
# Phones         3357
# Storage        5049
# Supplies       2407
# Tables          861
# Name: Returned.num.Times, dtype: int64

# %%
ord_ret3['Returned'] = ord_ret3['Returned'].fillna('No')

# %%
ord_ret3.sample(50)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 32313   42743    IZ-2013-CK220561-41492 2013-08-06 2013-08-12  Standard Class
# 43485   49853   PL-2015-BD1725103-42217 2015-08-01 2015-08-08  Standard Class
# 50884   44984    NI-2013-EB387095-41352 2013-03-19 2013-03-23  Standard Class
# 15416   10681   ES-2015-NS1850545-42307 2015-10-30 2015-11-04  Standard Class
# 42848    3670    US-2014-RH195105-41970 2014-11-27 2014-12-03  Standard Class
# 27159   18370   ES-2015-KH1669014-42120 2015-04-26 2015-05-01  Standard Class
# 35934   39567  CA-2015-LP17095140-42035 2015-01-31 2015-02-07  Standard Class
# 3122    18385   ES-2013-BG1103548-41594 2013-11-16 2013-11-22  Standard Class
# 42529   45105    SA-2013-AS240110-41590 2013-11-12 2013-11-16  Standard Class
# 49763   28861  ID-2015-HL15040102-42228 2015-08-12 2015-08-16  Standard Class
# 41446   50660    CG-2012-HR477033-41163 2012-09-11 2012-09-17  Standard Class
# ...

# %% [markdown]
# ### Problem 5: Fitting Models
#
# - You can use any binary classification method you have learned so far.
# - Use 80/20 training and test splits to build your model.
# - Double check the column types before you fit the model.
# - Only include useful features. i.e all the `ID`s should be excluded from your training set.
# - Note that there are only less than 5% of the orders have been returned, so you should consider using the [createDataPartition](https://www.rdocumentation.org/packages/caret/versions/6.0-80/topics/createDataPartition) function from `caret` package and [StratifiedKfold](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn-model-selection-stratifiedkfold) from sklearn when running cross-validation.
# - Do forget to `set.seed()` before the spilt to make your result reproducible.
# - **Note:** We are not looking for the best tuned model in the lab so don't spend too much time on grid search. Focus on model evaluation and the business use case of each model.

# %% [markdown]
# #### REMOVE FEATURES

# %%
to_remove=['Row.ID', 'Order.ID', 'Customer.ID', 'Postal.Code', 'Product.ID','Order ID', 'Region_y', 'index' ]
alt_to_remove=['Order.Date', 'Ship.Date', 'Customer.Name', 'Returned.num.Times']

# %%
ord_ret3.columns
# Out:
# Index(['Row.ID', 'Order.ID', 'Order.Date', 'Ship.Date', 'Ship.Mode',
#        'Customer.ID', 'Customer.Name', 'Segment', 'Postal.Code', 'City',
#        'State', 'Country', 'Region_x', 'Market', 'Product.ID', 'Category',
#        'Sub.Category', 'Product.Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping.Cost', 'Order.Priority', 'order.month', 'Returned',
#        'Order ID', 'Region_y', 'process.days', 'index', 'Returned.num.Times'],
#       dtype='object')

# %%
ord_ret4= ord_ret3.drop(to_remove, axis=1)

# %%
ord_ret4.sample(5)
# Out:
#       Order.Date  Ship.Date       Ship.Mode    Customer.Name      Segment  \
# 46210 2012-02-17 2012-02-22  Standard Class      Roger Demir     Consumer
# 10503 2014-04-18 2014-04-22    Second Class  Roy Französisch     Consumer
# 26905 2015-05-13 2015-05-17  Standard Class     Ralph Ritter     Consumer
# 23870 2015-12-29 2016-01-02  Standard Class     Joel Jenkins  Home Office
# 37914 2012-06-06 2012-06-08    Second Class   Dorothy Wardle    Corporate
#
#               City           State    Country           Region_x  \
# 46210        Lagos           Lagos    Nigeria     Western Africa
# 10503  Santa Clara     Villa Clara       Cuba          Caribbean
# 26905        Opole           Opole     Poland     Eastern Europe
# 23870       Dublin          Dublin    Ireland    Northern Europe
# 37914        Medan  Sumatera Utara  Indonesia  Southeastern Asia
#
#              Market         Category Sub.Category  \
# 46210        Africa  Office Supplies       Labels
# ...

# %%
#assign predictor and target variables
y = ord_ret4['Returned']
X = ord_ret4.drop(["Returned"], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
ord_ret4_alt= ord_ret4.drop(alt_to_remove, axis=1)
#assign predictor and target variables
yalt = ord_ret4_alt['Returned']
Xalt = ord_ret4_alt.drop(["Returned"], axis = 1)
Xalt_train, Xalt_test, yalt_train, yalt_test = train_test_split(Xalt, yalt, test_size = 0.2, random_state = 0, stratify=y)

# %% [markdown]
# #### LABEL ENCODING

# %%
# LABEL ENCODING
ord_ret4_alt_str= ord_ret4_alt.select_dtypes(["object","category"])
ord_ret4_alt_int= ord_ret4_alt.select_dtypes(["float64","int64"])

# %%
le = LabelEncoder()
ord_ret4_alt_str_le = ord_ret4_alt_str.apply(le.fit_transform, axis = 0)
column_le = ord_ret4_alt_str.columns.tolist()

# Combine the object and numeric features back again for train set
ord_ret4_alt_le =  pd.DataFrame(ord_ret4_alt_str_le, columns= column_le)
ord_ret4_alt_le.set_index(ord_ret4_alt_int.index, inplace = True)
ord_ret4_alt_le = pd.concat([ord_ret4_alt_le, ord_ret4_alt_int], axis = 1)

# %%
#assign predictor and target variables
yalt_le = ord_ret4_alt_le['Returned']
Xalt_le = ord_ret4_alt_le.drop(["Returned"], axis = 1)

Xalt_le_train, Xalt_le_test, yalt_le_train, yalt_le_test = train_test_split(Xalt_le, yalt_le, test_size = 0.2, random_state = 0,stratify=y)

# %% [markdown]
# #### KNN Model

# %%
# knn of entire dataset

knn = neighbors.KNeighborsClassifier()
## set the possible parameters from 3 to 30

# grid_param = {'n_neighbors': range(3, 31), 'metric': ['manhattan', 'minkowski', 'euclidean']}
# para_search = GridSearchCV(estimator=knn, param_grid=grid_param, scoring='accuracy', cv=5, return_train_score=True)
# para_search = para_search.fit(X, y.astype('int')) # y target must be integer type

knn.fit(Xalt_le, yalt_le)
knn.score(Xalt_le, yalt_le)
# Out:
# 0.9572821212712029

# %%
strat= ms.StratifiedKFold(n_splits=5, random_state=0)
scores = ms.cross_val_score(estimator=knn, X=Xalt_le, y=yalt_le, cv=5)
scores
# Out:
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# array([0.95574186, 0.95496198, 0.95564438, 0.95535192, 0.95671671])

# %%
# knn of train split only

knn = neighbors.KNeighborsClassifier()
## set the possible parameters from 3 to 30

# grid_param = {'n_neighbors': range(3, 31), 'metric': ['manhattan', 'minkowski', 'euclidean']}
# para_search = GridSearchCV(estimator=knn, param_grid=grid_param, scoring='accuracy', cv=5, return_train_score=True)
# para_search = para_search.fit(X, y.astype('int')) # y target must be integer type

knn.fit(Xalt_le_train, yalt_le_train)
knn.score(Xalt_le_train, yalt_le_train)
# Out:
# 0.9571066484694872

# %%
strat= ms.StratifiedKFold(n_splits=5, random_state=0)
scores = ms.cross_val_score(estimator=knn, X=Xalt_le_train, y=yalt_le_train, cv=5)
scores
# Out:
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# array([0.95552577, 0.95467284, 0.95564221, 0.95527663, 0.95515476])

# %%
# Test error vs. number of folds

mean_error = [] 
std_error = [] 
kfold = range(3, 50) 

for i in kfold:
    scores = ms.cross_val_score(knn, Xalt_le, yalt_le, cv=i) 
    mean_error.append(1 - scores.mean()) 
    std_error.append(scores.std())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-3efe6634f306> in <module>
#       6
#       7 for i in kfold:
# ----> 8     scores = ms.cross_val_score(knn, Xalt_le, yalt_le, cv=i)
#       9     mean_error.append(1 - scores.mean())
#      10     std_error.append(scores.std())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     399     scorer = check_scoring(estimator, scoring=scoring)
#     400
# ...

# %%
s1 = plt.scatter(kfold, mean_error, label='mean error') 
plt.plot(kfold, mean_error)
s2 = plt.scatter(kfold, std_error, color='red', label='std') 
plt.plot(kfold, std_error, color='red')
plt.xlim(0, 50)
plt.xlabel('Number of folds')
plt.legend(handles=[s1, s2], loc=2)
plt.show()

# %% [markdown]
# #### Confusion matrices

# %%
yalt_le_train
# 1794 returns / 41032 orders
# Out:
# 26524    0
# 24604    0
# 19693    0
# 12326    0
# 4673     0
# 3907     0
# 27867    0
# 39484    0
# 42114    0
# 28633    0
# 19863    0
# 18406    0
# 10855    0
# 38222    0
# 28194    0
# 35482    1
# 12014    0
# 23464    0
# 44594    0
# 26407    0
# 9155     0
# 44625    0
# 10903    0
# 43035    0
# 6774     0
# 32392    0
# 23772    0
# 48783    0
# 46275    0
# 18242    0
# 9844     0
# 5550     0
# 6770     0
# 33969    0
# 32086    0
# 13501    0
# 738      0
# 9436     0
# 21661    0
# 20269    0
# 42756    0
# 3820     0
# 23750    0
# 38538    0
# 20243    0
# 49629    0
# 48472    0
# 5773     0
# 19423    1
# 29335    0
# 9852     0
# 3175     0
# 42668    0
# 5235     0
# 17035    0
# 19077    0
# 34169    0
# 762      0
# 11529    0
# 30956    0
# 15733    0
# 38148    0
# 30386    0
# 24719    0
# 34218    0
# 1861     0
# 18704    0
# 34120    0
# 17672    0
# 31854    0
# 26153    0
# 27896    0
# 32037    0
# 46615    0
# 32060    0
# 22649    0
# ...

# %%
len(yalt_le_test[yalt_le_test==1])
# 426 returned / 10258 orders
# Out:
# 426

# %%
confusion_matrix(yalt_le_train, knn.predict(Xalt_le_train))
# Out:
# array([[39233,    23],
#        [ 1737,    39]])

# %%
confusion_matrix(yalt_le_test, knn.predict(Xalt_le_test))
# Out:
# array([[9806,    8],
#        [ 443,    1]])

# %% [markdown]
# #### Balance classes and recalculate Confusion matricies? Not sure if possible for KNN classifier

# %% [markdown]
# #### XGBoost Model

# %%
xgbc = XGBClassifier()
xgbc.fit(Xalt_le, yalt_le)
xgbc.score(Xalt_le, yalt_le)
# Out:
# 0.9646519789432638

# %%
xgbc = XGBClassifier()
xgbc.fit(Xalt_le_train, yalt_le_train)
print(xgbc.score(Xalt_le_train, yalt_le_train))
print(xgbc.score(Xalt_le_test, yalt_le_test))
# Out:
# 0.9665626827841685
# 0.9575940729186976

# %%
#Baseline train test Values
train_baseline_xgb = xgbc.predict(Xalt_le_train)
#RMSE_train = np.sqrt(mean_squared_error(yalt_le_train, train_baseline_xgb))

test_baseline_xgb = xgbc.predict(Xalt_le_test)
#RMSE_test = np.sqrt(mean_squared_error(yalt_le_test,test_baseline_xgb))

print("Baseline Values: ")
print("Accuracy for train data is: %.3f" %(xgbc.score(Xalt_le_train, yalt_le_train)))
print("Accuracy for test data is: %.3f" %(xgbc.score(Xalt_le_test,yalt_le_test)))
print("-" * 50)
#print("RMSE for train data is: %.3f" % RMSE_train)
#print("RMSE for test data is: %.3f" % RMSE_test)
# Out:
# Baseline Values:
# Accuracy for train data is: 0.967
# Accuracy for test data is: 0.958
# --------------------------------------------------

# %%
strat= XGBClassifier(n_splits=5, random_state=0)
scores = ms.cross_val_score(estimator=xgbc, X=Xalt_le, y=yalt_le, cv=5)
scores
# Out:
# array([0.95554689, 0.93946188, 0.95271983, 0.80395789, 0.55507896])

# %%
confusion_matrix(yalt_le_train, xgbc.predict(Xalt_le_train))
# Out:
# array([[39255,     1],
#        [ 1371,   405]])

# %%
confusion_matrix(yalt_le_test, xgbc.predict(Xalt_le_test))
# Out:
# array([[9811,    3],
#        [ 432,   12]])

# %% [markdown]
# ### XGBoost Random Forest Classifier

# %%
xgbrfc = XGBRFClassifier()
xgbrfc.fit(Xalt_le_train, yalt_le_train)
print(xgbrfc.score(Xalt_le_train, yalt_le_train))
print(xgbrfc.score(Xalt_le_test, yalt_le_test))
# Out:
# 0.956716708910119
# 0.956716708910119

# %%
confusion_matrix(yalt_le_test, xgbrfc.predict(Xalt_le_test))
# Out:
# array([[9814,    0],
#        [ 444,    0]])

# %% [markdown]
# ### XGBoost Feature Selection

# %%
fi=list(zip(Xalt_le_train.columns, xgbc.feature_importances_))
print(fi)
fi.sort(key=lambda t: t[1])
firem = [i for i in fi if i[1]>0.05]
# get column names only
colnam=[t[0] for t in  firem]
# Out:
# [('Ship.Mode', 0.058907975), ('Segment', 0.06933236), ('City', 0.06897852), ('State', 0.058877196), ('Country', 0.06148784), ('Region_x', 0.06560761), ('Market', 0.060689166), ('Category', 0.04359277), ('Sub.Category', 0.04532446), ('Product.Name', 0.043805752), ('Order.Priority', 0.0678421), ('Sales', 0.04603256), ('Quantity', 0.039000776), ('Discount', 0.049276903), ('Profit', 0.046281587), ('Shipping.Cost', 0.04226502), ('order.month', 0.06446738), ('process.days', 0.06823006)]

# %%
# new dataframe with reduced features
Xalt_le_train_red = Xalt_le_train[colnam]
Xalt_le_test_red = Xalt_le_test[colnam]

# %%
xgbc_red = XGBClassifier()
xgbc_red.fit(Xalt_le_train_red, yalt_le_train)
print(xgbc_red.score(Xalt_le_train_red, yalt_le_train))
print(xgbc_red.score(Xalt_le_test_red, yalt_le_test))
# Out:
# 0.967293819457984
# 0.9621758627412751

# %%
confusion_matrix(yalt_le_test, xgbc_red.predict(Xalt_le_test_red))
# Out:
# array([[9810,    4],
#        [ 384,   60]])

# %% [markdown]
# ### slight improvement in prediction accuracy with reduced feature set

# %% [markdown]
# ### Problem 6: Evaluating Models
# - What is the best metric to evaluate your model. Is accuracy good for this case?
# - Now you have multiple models, which one would you pick?
# - Can you get any clue from the confusion matrix? What is the meaning of precision and recall in this case? Which one do you care the most? How will your model help the manager make decisions?
# - **Note:** The last question is open-ended. Your answer could be completely different depending on your understanding of this business problem.

# %% [markdown]
# The data set is highly imbalanced so one would receive a high accuracy score with a negative prediction.
# Therefore, accuracy may not be the best evaluation metric. Other metrics that should be better are ROC curve or F1.
# F1 is harmonic mean of precision and recall:
# F1 = 2x(Precision * Recall/Precision + Recall)

# %%
# ROC AUC for XGBoost classifier with reduced dataset after feature selection ():
print(roc_auc_score(yalt_le_train,xgbc_red.predict(Xalt_le_train_red)))
print(roc_auc_score(yalt_le_test,xgbc_red.predict(Xalt_le_test_red)))
# Out:
# 0.622453479309756
# 0.5673637770642049

# %%
plot_roc_curve(xgbc_red, Xalt_le_test_red,yalt_le_test)

# %%
fpr, tpr, thresholds = roc_curve(yalt_le_test, xgbc_red.predict(Xalt_le_test_red))
roc_auc = auc(fpr, tpr)
display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='example estimator')
display.plot()  
plt.show()

# %%
# F1 for XGBoost classifier with reduced dataset after feature selection (ranges from 0 to 1, perfect score is 1):
print(f1_score(yalt_le_train,xgbc_red.predict(Xalt_le_train_red)))
print(f1_score(yalt_le_test,xgbc_red.predict(Xalt_le_test_red)))
# Out:
# 0.3933092224231465
# 0.2362204724409449

# %% [markdown]
# F1 score appears to be a more precise metric for this type of classifier as it more closely represents what predictions are given by the confusion matrix.

# %% [markdown]
# ### Problem 7: Feature Engineering Revisit
# - Is there anything wrong with the new feature we generated? How should we fix it?
# - ***Hint***: For the real test set, we do not know it will get returned or not.

# %% [markdown]
# The new feature depends on the output y variable!
# This allows leakage of information into the test dataset during train/test splitting.
# Data could be split another way maybe by time.
